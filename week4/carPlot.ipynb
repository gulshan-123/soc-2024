# %%
from mountain_car import QAgent
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
np.random.seed(85)
# %matplotlib inline

# %%
plt.style.use('fivethirtyeight')
params = {
    'figure.figsize': (15, 8),
    'font.size': 24,
    'legend.fontsize': 20,
    'axes.titlesize': 28,
    'axes.labelsize': 24,
    'xtick.labelsize': 20,
    'ytick.labelsize': 20
}
pylab.rcParams.update(params)
np.set_printoptions(suppress=True)

# %%
agent = QAgent("MountainCar-v0")
q_table, q_track, meanRewards=agent.train(eval_intervals=100000000) # Change the number to change frequency of evaluation-->No evavluation neede in notebook
# Out:
# Episode: 0

# %%
meanRewards[meanRewards!=-1] # unfortunately, all the meanReward are -1, i.e, the agent never reaches the goal
# Out:
# array([], dtype=float64)

# %% [markdown]
# ### Why the agent never reached the goal
# The exploration is not enough, it didn't try to go near the last states

# %% [markdown]
# ## Plots

# %%
plt.plot(range(agent.num_train_episodes),meanRewards)
plt.savefig('avgRewards.png')
plt.show()
